# %% [markdown]
# Run : shift + enter
#
# Help: tab

# %%
print("Hello ElHamma")
# Out:
# Hello ElHamma

# %%
name = "Marwan"

# %%
print("Hello "+name)
# Out:
# Hello Marwan

# %%
def SayHello(name):
    print("Hello "+name)

# %%
SayHello("Marwan")
# Out:
# Hello Marwan

# %%
names = ["Mohamed","Lassad","Safouan","Lotfi"]

# %%
for n in names:
    SayHello(n)
# Out:
# Hello Mohamed
# Hello Lassad
# Hello Safouan
# Hello Lotfi

# %% [markdown]
# #### Import

# %%
import numpy

# %%
print(numpy.__version__)
# Out:
# 1.15.4

# %%
print(numpy.sum((1,2)))
# Out:
# 3

# %% [markdown]
# ### why lib ?
# - tasks already done
# - distribution and optimisation

# %%
import cv2

# %%
image = cv2.imread("img/image.png")
print(image)
# Out:
# [[[108 117 125]
#   [107 116 124]
#   [106 116 120]
#   ...
#   [ 22  51  39]
#   [ 12  49  32]
#   [ 37  75  58]]
#
#  [[110 119 127]
#   [110 118 126]
#   [108 118 122]
#   ...
#   [ 33  62  50]
#   [ 23  59  42]
#   [ 36  74  57]]
#
#  [[116 122 128]
#   [115 121 127]
#   [114 120 126]
#   ...
#   [ 19  51  40]
#   [ 18  53  39]
#   [ 26  63  49]]
#
#  ...
#
#  [[ 52  38 163]
#   [ 58  41 168]
#   [ 64  48 174]
#   ...
#   [ 57  68 108]
#   [ 51  61 101]
#   [ 51  61 101]]
#
#  [[ 36  18 146]
#   [ 47  32 158]
#   [ 60  43 170]
#   ...
#   [ 28  37  72]
#   [ 19  30  62]
#   [ 20  27  61]]
#
#  [[ 38  21 148]
#   [ 52  38 163]
#   [ 66  50 176]
#   ...
#   [  5  10  43]
#   [  0   4  32]
#   [  0   2  31]]]

# %%
#importing some useful packages
import matplotlib.pyplot as plt

# %%
plt.imshow(image)
plt.show()

# %%
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
