# %% [markdown]
# ### Started 04/12/2018

# %%
pathImages = "new"
pathOutput = "result"
ext = ".jpg"

# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')

# %%
def ProcessFolder(inputPath,outputPath,extension):
    i = 0
    for file in tqdm(os.listdir(inputPath)):
        if file.endswith(extension):
            path = inputPath+"/"+file
            img = cv2.imread(path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
            faces = face_cascade.detectMultiScale(gray, 1.1, 5)
            original = img.copy()
            for (x,y,w,h) in faces:
                cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
                crop_img = original[y:y+h, x:x+w]
                crop_img = cv2.cvtColor(crop_img, cv2.COLOR_BGR2RGB)
                file_name = outputPath+"/"+"%s.jpg"% (i)
                cv2.imwrite( file_name, crop_img );
                i = i+1

# %%
images = ["test1.jpg","test2.jpg","test3.jpg"]
img = cv2.imread(images[0])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray,cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-9-24dcd2eccbef> in <module>
#       1 images = ["test1.jpg","test2.jpg","test3.jpg"]
#       2 img = cv2.imread(images[0])
# ----> 3 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       4 plt.imshow(img)
#       5 plt.show()
#
# error: OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/imgproc/src/color.hpp:253: error: (-215:Assertion failed) VScn::contains(scn) && VDcn::contains(dcn) && VDepth::contains(depth) in function 'CvtHelper'

# %%
faces = face_cascade.detectMultiScale(img, 1.1, 5)
original = img.copy()
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
# cv2.imshow('img',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.imshow(img)
plt.show()

# %%
import time
import os

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imwrite( "result.jpg", img );

# %% [markdown]
# ### Crop image

# %%
i = 0;
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    crop_img = original[y:y+h, x:x+w]
    crop_img = cv2.cvtColor(crop_img, cv2.COLOR_BGR2RGB)
    file_name = "face%s.jpg"% (i)
    cv2.imwrite( file_name, crop_img );
    i = i+1
